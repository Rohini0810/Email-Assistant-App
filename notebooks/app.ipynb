# %% [markdown]
# Local AI Email Assistant, using only free, open-source tools that run on your own computer.
#
# To build a Local AI Project, you need two main parts: an inference engine to run the model and a framework to create the user interface.
#
# Ollama: This tool lets you run large language models on your own machine. It handles the complicated setup that local ML inference usually needs.
#
# Streamlit: If you don’t have time to learn React just to make a prototype, Streamlit is a Python library that lets you turn data scripts into web apps in minutes.
#
# Before we get to the code, set up your environment:
#
# Download and install Ollama.
#
# Open your terminal and pull the Llama 3 model by running: ollama pull llama3.
# Install the required Python libraries: pip install streamlit ollama.
#
# https://amanxai.com/2026/07/01/build-an-end-to-end-local-ai-project/

# %%
# %pip install langchain langchain-ollama streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (1.4.0)
# Requirement already satisfied: langchain-ollama in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (1.1.0)
# Requirement already satisfied: streamlit in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (1.63.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain) (1.6.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.15.1)
# Requirement already satisfied: certifi in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: ollama<1.0.0,>=0.6.1 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from langchain-ollama) (0.6.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=5.0.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.2.2)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.5.3)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (3.0.5)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (12.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.9.3)
# Requirement already satisfied: protobuf<8,>=5.26.1 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (7.36.1)
# Requirement already satisfied: pyarrow!=25.0.0,<26,>=7.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (25.0.1)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: starlette<2,>=0.46.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (1.6.0)
# Requirement already satisfied: uvicorn<1,>=0.30.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.52.4)
# Requirement already satisfied: httptools<1,>=0.6.3 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: python-multipart<1,>=0.0.10 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: itsdangerous<3,>=2.1.2 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2.25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=5.0.0->streamlit) (2026.6.3)
# Requirement already satisfied: six>=1.5 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from langchain_ollama import ChatOllama

# %%
import streamlit as st
from langchain_ollama import ChatOllama


# 1. Page Configuration
st.set_page_config(
    page_title="Local AI Email Assistant",
    page_icon="✉️",
    layout="centered",
)

st.title("✉️ Local AI Email Responder")
st.write("Turn your rough notes into a professional email, running 100% locally.")


# 2. User Inputs
tone = st.selectbox(
    "Select Email Tone",
    ["Professional", "Friendly", "Apologetic", "Direct"],
)

user_input = st.text_area(
    "Enter your rough draft or notes here:",
    height=150
)


# 3. Create the Ollama connection
llm = ChatOllama(
    model="llama3.2:3b",
    base_url="http://localhost:11434",
)


# 4. The Core Logic
if st.button("Generate Professional Email"):

    if not user_input.strip():
        st.warning("Please enter some text to get started.")

    else:

        with st.spinner("Drafting your email..."):

            # 5. Prompt Engineering
            system_prompt = f"""
            You are an expert corporate communicator.

            Your task is to rewrite the user's rough notes
            into a well-structured, grammatically correct email.

            The tone of the email must be: {tone}.

            Do not include any explanations or pleasantries
            in your output, just the email itself.
            """

            # 6. Local Model Invocation
            try:

                response = llm.invoke([
                    ("system", system_prompt),
                    ("human", user_input)
                ])

                # 7. Displaying the Output
                st.subheader("Your Polished Email:")
                st.info(response.content)

            except Exception as e:

                st.error(
                    f"An error occurred: {e}. "
                    "Make sure your Ollama Docker container is running."
                )
# Out:
# 2026-09-11 23:02:15.729 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:15.735 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.747
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\HP\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-09-11 23:02:16.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.778 Session state does not function when running a script without `streamlit run`
# 2026-09-11 23:02:16.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:16.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:17.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:17.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:17.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:17.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-11 23:02:17.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
